# %% [markdown]
# <a href="https://colab.research.google.com/github/putriseptianabilah/deteksi_mangrove/blob/main/mangrove.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LANGKAH 1 : Persiapan trainning Model**
#
# Hubungkan terlebih dahulu google colab dengan google drive kemudian ubah runtime dengan GPU agar dalam proses training menjadi lebih cepat.
#
# setelah itu, install ultralytics terlebih dahulu dengan perintah sebagai berikut:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.2/721.2 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 62.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 69.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 76.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# **LANGKAH 2 : Mulai Trainning**
#
# jalankan perintah untuk mengimport ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 28.9/78.2 GB disk)

# %% [markdown]
# **LANGKAH 3 : Trainning dataset**
#
# jalankan perintah untuk mengtrain dataset, kemudian masukkan data.yml yang sudah diedit pada bagian train dan val dengan memasukan alamat penyimpanan yang sesuai pada drive.
#
# untuk memasukan data drive dapat dilakukan dengan mengklik pada menu bagian drive > dilanjut my drive > kemudian copy path pada data.yml

# %%
# !yolo detect train data=/content/drive/MyDrive/data.yaml
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# **LANGKAH 4 : Testing Dataset**
#
# ujicoba dataset dari hasil trainning dengan menggunakan perintah sebagai berikut:

# %%
# !yolo detect predict model= /content/runs/detect/train3/weights/best.pt source=/content/drive/MyDrive/valid/images/IMG20230118170343_jpg.rf.a8c0f161632d1a701da6d9b8234e8f98.jpg save=true
# Out:
# Ultralytics YOLOv8.1.27 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3007208 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/valid/images/IMG20230118170343_jpg.rf.a8c0f161632d1a701da6d9b8234e8f98.jpg: 640x640 1 Rhizopora-Styllosa, 11.5ms
# Speed: 2.8ms preprocess, 11.5ms inference, 645.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# ![IMG20221211154215_jpg.rf.fd1ecc7e84d6ecd7acec80261e674ee1.jpg](data:image/jpeg;base64,...)![IMG20230130121131_jpg.rf.5a1fa55dfe8c6ca1424eac4fc281a533.jpg](data:image/jpeg;base64,...)![IMG20230119101818_jpg.rf.d983841883d547ac3a20e7f86e51ce7f.jpg](data:image/jpeg;base64,...)![IMG20230118170343_jpg.rf.a8c0f161632d1a701da6d9b8234e8f98.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **TESTING MENGGUNAKAN WEBCAM**
#
# download data best.pt kemudian jalankan pada aplikasi visual studio kode
